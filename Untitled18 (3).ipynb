# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-300c5f12-9b0e-4206-a350-11529436fc7a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-300c5f12-9b0e-4206-a350-11529436fc7a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('medical_aid_claims.csv')
df.head()
# Out:
#   member-name                     email  gender   location   employer  \
# 0       Chipi        ajimmison0@sun.com  female     Kwekwe       Vipe
# 1       Femba     rsoonhouse1@google.it  female  Marondera       Mudo
# 2        Geta  bchecchetelli2@house.gov  female     Rusape     Skaboo
# 3    Tichaona          mgarman3@psu.edu  female     Rusape  Babbleset
# 4       Chisa     ccough4@biglobe.ne.jp  female   Bulawayo   Flipopia
#
#   relationship patient_name  patient_suffix patient_dob  \
# 0  Grandfather      Mabhena             789  09-11-1997
# 1      Husband      Sithole             860   1-14-1992
# 2       Mother        Chipi             374  07-03-1999
# 3       Father       Jembwa             729   7-31-1978
# 4       Father         Foto             716  12-28-1992
#
#                    cause  Fee Charged  membership_period  number_of_claims  \
# 0                  Other         3798               1541                 2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   member-name           7000 non-null   object
#  1   email                 7000 non-null   object
#  2   gender                7000 non-null   object
#  3   location              7000 non-null   object
#  4   employer              7000 non-null   object
#  5   relationship          7000 non-null   object
#  6   patient_name          7000 non-null   object
#  7   patient_suffix        7000 non-null   int64
#  8   patient_dob           7000 non-null   object
#  9   cause                 7000 non-null   object
#  10  Fee Charged           7000 non-null   int64
#  11  membership_period     7000 non-null   int64
#  12  number_of_claims      7000 non-null   int64
#  13  number_of_dependants  7000 non-null   int64
#  14  fraud                 7000 non-null   int64
# ...

# %%
df.shape
# Out:
# (7000, 15)

# %%
df.isnull().sum()
# Out:
# member-name             0
# email                   0
# gender                  0
# location                0
# employer                0
# relationship            0
# patient_name            0
# patient_suffix          0
# patient_dob             0
# cause                   0
# Fee Charged             0
# membership_period       0
# number_of_claims        0
# number_of_dependants    0
# fraud                   0
# dtype: int64

# %%
df.columns
# Out:
# Index(['member-name', 'email', 'gender', 'location', 'employer',
#        'relationship', 'patient_name', 'patient_suffix', 'patient_dob',
#        'cause', 'Fee Charged', 'membership_period', 'number_of_claims',
#        'number_of_dependants', 'fraud'],
#       dtype='object')

# %%
df.describe()
# Out:
#        patient_suffix   Fee Charged  membership_period  number_of_claims  \
# count     7000.000000   7000.000000        7000.000000       7000.000000
# mean       549.738857  25464.071429        4521.435143          3.448000
# std        259.634041  14336.311377        2576.064241          1.707378
# min        100.000000    503.000000         100.000000          1.000000
# 25%        323.000000  12864.250000        2298.750000          2.000000
# 50%        549.000000  25469.000000        4485.000000          3.000000
# 75%        777.000000  37870.750000        6752.250000          5.000000
# max        999.000000  49998.000000        9000.000000          6.000000
#
#        number_of_dependants        fraud
# count           7000.000000  7000.000000
# mean               2.479000     0.197000
# std                1.119704     0.397761
# min                1.000000     0.000000
# 25%                1.000000     0.000000
# 50%                2.000000     0.000000
# ...

# %%
num_col=df.select_dtypes(include=np.number).columns
print(num_col)
cat_col=df.select_dtypes(include=object).columns
print(cat_col)
# Out:
# Index(['patient_suffix', 'Fee Charged', 'membership_period',
#        'number_of_claims', 'number_of_dependants', 'fraud'],
#       dtype='object')
# Index(['member-name', 'email', 'gender', 'location', 'employer',
#        'relationship', 'patient_name', 'patient_dob', 'cause'],
#       dtype='object')

# %%
corr=df[num_col].corr()
corr
# Out:
#                       patient_suffix  Fee Charged  membership_period  \
# patient_suffix              1.000000    -0.018051          -0.005959
# Fee Charged                -0.018051     1.000000           0.004625
# membership_period          -0.005959     0.004625           1.000000
# number_of_claims            0.002866    -0.014635          -0.001084
# number_of_dependants       -0.008423    -0.010560          -0.019292
# fraud                      -0.001051     0.011846          -0.010831
#
#                       number_of_claims  number_of_dependants     fraud
# patient_suffix                0.002866             -0.008423 -0.001051
# Fee Charged                  -0.014635             -0.010560  0.011846
# membership_period            -0.001084             -0.019292 -0.010831
# number_of_claims              1.000000             -0.020563 -0.005216
# number_of_dependants         -0.020563              1.000000 -0.015572
# ...

# %%
plt.figure(figsize=(10,10))
sns.heatmap(corr,annot=True)
plt.show()

# %%
plt.figure(figsize=(10,10))
sns.pairplot(df)
plt.show()

# %%
df.columns
# Out:
# Index(['member-name', 'email', 'gender', 'location', 'employer',
#        'relationship', 'patient_name', 'patient_suffix', 'patient_dob',
#        'cause', 'Fee Charged', 'membership_period', 'number_of_claims',
#        'number_of_dependants', 'fraud'],
#       dtype='object')

# %%
sns.barplot(x='cause',y='Fee Charged',data=df,palette='pastel')
plt.show()

# %%
sns.barplot(x='location',y='Fee Charged',data=df,palette='pastel',hue='gender')
plt.xticks(rotation=90)
plt.show()

# %%
figsize=(15,15)
sns.barplot(x='location',y='membership_period',data=df,palette='muted',hue='cause')
plt.xticks(rotation=90)
plt.show()
#

# %%
sns.barplot(x='number_of_claims',y='fraud',data=df,palette='muted',hue='gender')
plt.xticks(rotation=90)
plt.show()
#

# %%
plt.pie(df['cause'].value_counts(),labels=df['cause'].value_counts().index,autopct='%1.2f%%')
plt.show()

# %%
sns.barplot(x='location',y='fraud',data=df,palette='muted',hue='gender')
plt.xticks(rotation=90)
plt.show()
#

# %%
df.columns
# Out:
# Index(['member-name', 'email', 'gender', 'location', 'employer',
#        'relationship', 'patient_name', 'patient_suffix', 'patient_dob',
#        'cause', 'Fee Charged', 'membership_period', 'number_of_claims',
#        'number_of_dependants', 'fraud'],
#       dtype='object')

# %%
df['gender'].unique()
# Out:
# array(['female', 'male'], dtype=object)

# %%
df['employer'].unique()
# Out:
# array(['Vipe', 'Mudo', 'Skaboo', 'Babbleset', 'Flipopia', 'Brainverse',
#        'Photobug', 'Avamba', 'Feedspan', 'Fiveclub', 'Fanoodle',
#        'Bubblebox', 'Twitterbeat', 'Demimbu', 'Dynazzy', 'Twitterwire',
#        'Buzzbean', 'Eayo', 'Quimm', 'Avavee', 'Geba', 'Realcube',
#        'Skinder', 'Meembee', 'LiveZ', 'Blogtags', 'JumpXS', 'Brightdog',
#        'Edgeify', 'Meemm', 'Chatterpoint', 'Tagpad', 'Yadel', 'Voolia',
#        'Youopia', 'Cogibox', 'Jayo', 'Jamia', 'Abatz', 'Eimbee',
#        'Zoonoodle', 'Photospace', 'Tazzy', 'Leexo', 'Miboo', 'Mycat',
#        'Mybuzz', 'Linkbuzz', 'Thoughtblab', 'Oloo', 'Twitterworks',
#        'Devify', 'Yodel', 'Quire', 'Kwideo', 'Yambee', 'Jetpulse',
#        'Jabberstorm', 'Chatterbridge', 'Gabcube', 'Devbug', 'Browseblab',
#        'Yodo', 'Meezzy', 'Midel', 'Browsedrive', 'Voonte', 'Youspan',
#        'Kimia', 'Realblab', 'Pixonyx', 'Kwilith', 'Feedbug', 'Rhybox',
# ...

# %%
df['gender']=df['gender'].map({'M':0,'F':1})
df['employer']=df['employer'].map({'Yes':1,'No':0})

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
df['cause']=le.fit_transform(df['cause'])
df['location']=le.fit_transform(df['location'])
df['gender']=le.fit_transform(df['gender'])
df['employer']=le.fit_transform(df['employer'])
df['location'].unique()
# Out:
# array([ 6,  7, 11,  1, 10,  4,  8,  3,  9,  2,  5,  0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   member-name           7000 non-null   object
#  1   email                 7000 non-null   object
#  2   gender                7000 non-null   int64
#  3   location              7000 non-null   int64
#  4   employer              7000 non-null   int64
#  5   relationship          7000 non-null   object
#  6   patient_name          7000 non-null   object
#  7   patient_suffix        7000 non-null   int64
#  8   patient_dob           7000 non-null   object
#  9   cause                 7000 non-null   int64
#  10  Fee Charged           7000 non-null   int64
#  11  membership_period     7000 non-null   int64
#  12  number_of_claims      7000 non-null   int64
#  13  number_of_dependants  7000 non-null   int64
#  14  fraud                 7000 non-null   int64
# ...

# %%
df['member-name']=df['member-name'].str.split(' ').str[0]
df.head()
df['member-name'].dropna()
# Out:
# 0          Chipi
# 1          Femba
# 2           Geta
# 3       Tichaona
# 4          Chisa
#           ...
# 6995       Mirwa
# 6996       Chisa
# 6997       Evans
# 6998       Femba
# 6999     Sithole
# Name: member-name, Length: 7000, dtype: object

# %%
from sklearn.model_selection import train_test_split
x=df.drop(['member-name', 'email','relationship', 'patient_name', 'patient_dob', 'fraud'],axis=1)
y=df['fraud']
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((5600, 9), (1400, 9), (5600,), (1400,))

# %%
from sklearn.preprocessing import StandardScaler
sc  = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)
x_train = pd.DataFrame(x_train, columns = ['gender', 'location', 'employer', 'patient_suffix', 'cause', 'Fee Charged', 'membership_period', 'number_of_claims', 'number_of_dependants'])
x_test = pd.DataFrame(x_test, columns =  ['gender', 'location', 'employer', 'patient_suffix', 'cause', 'Fee Charged', 'membership_period', 'number_of_claims', 'number_of_dependants'])

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
y_pred=rf.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.8064285714285714

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.8078571428571428

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, r2_score, mean_absolute_error, mean_squared_error
dt=DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_pred=dt.predict(x_test)
accuracy_score(y_test,y_pred)
from sklearn.svm import SVC
svc=SVC()
svc.fit(x_train,y_train)
y_pred=svc.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.8078571428571428

# %%
r2_score(y_test,y_pred)
# Out:
# -0.23784261715296218

# %%
from sklearn.metrics import confusion_matrix
confusion_matrix(y_test,y_pred)
#
# Out:
# array([[1131,    0],
#        [ 269,    0]])

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
#
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      1.00      0.89      1131
#            1       0.00      0.00      0.00       269
#
#     accuracy                           0.81      1400
#    macro avg       0.40      0.50      0.45      1400
# weighted avg       0.65      0.81      0.72      1400

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(x_train,y_train)
y_pred=knn.predict(x_test)
accuracy_score(y_test,y_pred)
#
# Out:
# 0.7671428571428571

# %%
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression

from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
grid_param={
    'n_estimators':[90,100,115],
    'criterion':['gini','entropy'],
    'max_depth':range(2,20,1),
    'max_features':['auto','log2']
}
grid_search=GridSearchCV(estimator=rf,param_grid=grid_param,cv=5,n_jobs=-1,verbose=3)
grid_search.fit(x_train,y_train)
grid_search.best_params_
grid_search.best_score_
rf_best=grid_search.best_estimator_
rf_best.fit(x_train,y_train)
y_pred=rf_best.predict(x_test)
accuracy_score(y_test,y_pred)
# Out:
# Fitting 5 folds for each of 216 candidates, totalling 1080 fits
# 0.8078571428571428
